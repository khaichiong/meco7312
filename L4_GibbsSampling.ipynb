# %% [markdown]
# <a href="https://colab.research.google.com/github/khaichiong/meco7312/blob/master/L4_GibbsSampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sampling from a Multivariate Normal via Gibbs sampling

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Consider $(X,Y)$ bivariate Normal.
#
# The conditional distribution of Y given X is:
# $$(Y|X = x) \sim N\Big(\mu_Y + \rho \frac{\sigma_{Y}}{\sigma_{X}}(x -\mu_{X}), (1-\rho^{2})\sigma_{Y}^{2}\Big) $$

# %% [markdown]
# To implement Gibbs' sampling, we first sample from the marginal pdf of $X$.

# %%
#Set the following parameters for the bivariate Normal distribution
mu_x = 0.2
mu_y = -0.5
sigma_x = 1.0
sigma_y = 1.0
rho = 0.6

# %%
#sample from the marginal pdf of X
n = 1000
x = np.random.normal(mu_x,sigma_x,n)

# %% [markdown]
# Draw from the conditonal distribution $Y|X=x$

# %%
mu_conditional = mu_y + rho*(sigma_y/sigma_x)*(x-mu_x)
sigma_conditional = np.sqrt((1-rho**2)*sigma_y**2)
y = np.random.normal(mu_conditional,sigma_conditional,n)

# %% [markdown]
# Plot the sample to see if the distribution resembles a bivariate distribution

# %%
plt.scatter(x,y)

# %%
plt.hist2d(x, y, (25, 25), cmap=plt.cm.jet,density=True)
plt.colorbar()

# %% [markdown]
# Try different correlation and sample size

# %% [markdown]
# ## Two random variables that are each marginally Normal, but not jointly Normal

# %%
n = 1000
x = np.random.normal(0,1,n)

# %%
u = np.random.binomial(1,0.5,n)
u = 2*u-1

# %%
y = x*u

# %%
sns.kdeplot(x)

# %%
sns.kdeplot(y)

# %%
sns.kdeplot(x=x,y=y)
